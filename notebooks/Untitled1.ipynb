# %%
import geopandas as gpd
from silrec.utils.shapefile_silvers_merger import ShapefileSliversMerger
from silrec.utils.plot_utils import plot_gdf, plot_overlay

#%matplotlib inline
# %matplotlib notebook

# %%
gdf_single = gpd.read_file('~/projects/silrec/silrec/utils/Shapefiles/demarcation_single/demarcation_single_feature.shp')
