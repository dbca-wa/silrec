# %%
import geopandas as gpd
from silrec.utils.shapefile_silvers_merger import ShapefileSliversMerger
from silrec.utils.plot_utils import plot_gdf, plot_overlay, plot_multi

import warnings
warnings.filterwarnings('ignore') # suppress warnings

from IPython.display import display, HTML
display(HTML("<style>.container { width:80% ! important; }</style>"))

#%matplotlib inline
# %matplotlib notebook
# Out:
# <style>.container { width:80% ! important; }</style>

# %%
gdf_single = gpd.read_file('~/projects/silrec/silrec/utils/Shapefiles/demarcation_1_polygons/Demarcation_Boundary_1_polygons.shp')
gdf_single.to_crs('EPSG:28350', inplace=True)

gdf_full = gpd.read_file('~/projects/silrec/silrec/utils/Shapefiles/demarcation_16_polygons/Demarcation_Boundary_16_polygons.shp')
gdf_full.to_crs('EPSG:28350', inplace=True)

ssm = ShapefileSliversMerger(gdf_single)
gdf_result = ssm.create_gdf()

# %%
len(gdf_full)
# Out:
# 16

# %% [markdown]
# ## The Shapefile Polygons

# %%
gdf_full.columns
gdf_full
# Out:
#         fea_id       Area  Region   Block            Block_cpt Compno Comment  \
# 0   DOGO010023  42.523451  WARREN  Gordon  Gordon01 Jarrah Nth     01    None
# 1   DOGO010023  26.286468  WARREN  Gordon  Gordon01 Jarrah Nth     01    None
# 2   DOGO010023  19.660914  WARREN  Gordon  Gordon01 Jarrah Nth     01    None
# 3   DOGO010023  27.496257  WARREN  Gordon  Gordon01 Jarrah Nth     01    None
# 4   DOGO010023   8.809338  WARREN  Gordon  Gordon01 Jarrah Sth     01    None
# 5   DOGO010023  59.225515  WARREN  Gordon  Gordon01 Jarrah Nth     01    None
# 6   DOGO010023   9.468592  WARREN  Gordon  Gordon01 Jarrah Sth     01    None
# 7   DOGO010023  26.887291  WARREN  Gordon  Gordon01 Jarrah Nth     01    None
# 8   DOGO010023  35.627445  WARREN  Gordon  Gordon01 Jarrah Nth     01    None
# 9   DOGO010023  11.095184  WARREN  Gordon  Gordon01 Jarrah Sth     01    None
# 10  DOGO010023   0.268243  WARREN  Gordon   Gordon01 Karri Sth     01    None
# ...

# %%
plot_gdf(gdf_full)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## First Polygon

# %%
ssm.plot_gdf_single
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Retrieve from Silrec_v3 Database all 'non-closed' (active) polygons that intersect with 'base polygon'

# %%
len(ssm.polygons_intersecting_single)
ssm.polygons_intersecting_single
#ssm.polygons_intersecting_single[['polygon_id','name','compartment','area_ha']]
# Out:
#        polygon_id        name compartment    area_ha sp_code  \
# 53084      420025  MAN070118        MAN07  30.297822    None
# 53092      420061  MAN060228        MAN06  15.445313    None
# 53155      420080  MAN060213        MAN06  12.168608    None
# 53252      420177  MAN070132        MAN07   8.131689    None
# 53341      420257  MAN070130        MAN07   5.130747    None
# 57194      424215  MGO018018        MGO01   0.747512    None
# 57244      424190  MGO018019        MGO01   0.429460    None
# 57256      424207  MGO018002        MGO01  75.306975    None
# 57263      424213  MGO01KS01        MGO01  10.879843    None
#
#                       created_on  \
# 53084 2024-11-27 15:39:29.364227
# 53092 2024-11-27 15:39:29.364227
# 53155 2024-11-27 15:39:29.364227
# 53252 2024-11-27 15:39:29.364227
# 53341 2024-11-27 15:39:29.364227
# 57194 2024-11-27 15:39:29.364227
# 57244 2024-11-27 15:39:29.364227
# 57256 2024-11-27 15:39:29.364227
# 57263 2024-11-27 15:39:29.364227
#
# ...

# %%
ssm.plot_hist_polygons
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Overlay 'base polygon' onto intersecting historical active polygons

# %%
len(ssm.gdf_overlay.explode())
#ssm.gdf_overlay.explode()
# Out:
# 45

# %%
ssm.plot_overlay
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
len(ssm.gdf_overlay)
# Out:
# 18

# %% [markdown]
# ## Retrieve Land Slivers based on polygon (Area/Length < Threshold)

# %%
gdf_slivers = ssm.gdf[ssm.gdf.geometry.area/ssm.gdf.geometry.length < 5]
len(gdf_slivers)
# Out:
# 27

# %%
ssm.gdf.geometry.area/ssm.gdf.geometry.length < 5
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 36     True
# 37    False
# 38     True
# dtype: bool

# %%
plot_gdf(gdf_slivers)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Add 'base polygon' (user provided from shapefile) to the slivers

# %%
plot_multi([ssm.gdf_slivers_plus_base, ssm.gdf_slivers_merged])
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %% [markdown]
# ## Merge - slivers with the base polygon

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% ! important; }</style>"))
ssm.plot_slivers_merged
# Out:
# <style>.container { width:100% ! important; }</style>
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Final Result (1st iteration) - Historical Polygons vs New Split Polygons

# %%
plot_multi([ssm.polygons_intersecting_single, ssm.gdf_result])
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
len(ssm.gdf_new_hist_polygons)
# Out:
# 10

# %%
len(ssm.gdf_result)
# Out:
# 11

# %%
len(ssm.gdf_slivers)
# Out:
# 27

# %% [markdown]
# # Functional Logic
#
# 1. Read/Upload Shapefile (Assume, initially, there is only a single polygon)
# 2. Convert to JSON (REST API)
# 3. Display Polygon on Vus.js Map Component
# 4. Display (Toggle button on map) historical 'active' Silrec_v3 polygons that intersect with Shpfile Polygon
# 3. Add Dashboard to list the displayed polygon(s)
#    a. Action button - to split intersected polygons
#    b. Action button - to merge slivers to base_polygon
#    c. Action button - to accept new polygon split layout

# %%
ssm.gdf_result['Area'] = ssm.gdf_result.area

# %%
ssm.gdf_result['Area']
# Out:
# 0     266523.834203
# 1     302918.627911
# 2     153841.760672
# 3     118610.302106
# 4      81232.992702
# 5      51295.401562
# 6       7474.915560
# 7       1492.384851
# 8       2802.095605
# 9     491249.112230
# 10    107938.761206
# Name: Area, dtype: float64

# %%
        ssm.gdf_result.iloc[0]
# Out:
# geometry      MULTIPOLYGON (((397891.80903214397 6219709.387...
# fea_id                                               DOGO010023
# Area                                              266523.834203
# Region                                                   WARREN
# Block                                                    Gordon
# Block_cpt                                   Gordon01 Jarrah Nth
# Compno                                                       01
# Comment                                                    None
# Ops_status                                            Exclusion
# target_ba_                                                    0
# Veg_comple                                                 None
# Lmu                                                        None
# herbicide_                                                 None
# Zone                                                       None
# compartmen                                                MGO01
# ...
